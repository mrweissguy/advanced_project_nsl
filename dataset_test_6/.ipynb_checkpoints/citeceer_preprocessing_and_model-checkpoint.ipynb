# %% [markdown]
# # Neural graph learning on Citeseer dataset

# %% [markdown]
# ## Introduction to the dataset
#
# The [Citeseer dataset](https://linqs.soe.ucsc.edu/data) consists of two parts - 3312 scientific publications and a graph structure.
# Each publication has an Id, one-hot representaiton of word attributes and a label indicating the type of publication. The publications are classified into one of six categories. Theres is a total of 3703 unique words in the vocabulary. Removing stopwords, stemming and removal of infrequent words was already done to the dataset.
# In the graph data each node is a publication and a link is formed between the nodes when one has citet the other.
#
# In our experiment we consider the graph to be bidirectional as the the graph is considered a measure of similarity between the papers and the direction of the link does not offer additional insight.
#
# To read more about other papers that used the same dataset, see [Qing Lu, and Lise Getoor. "Link-based classification." ICML, 2003.](https://linqspub.soe.ucsc.edu/basilic/web/Publications/2003/lu:icml03/) and  [Prithviraj Sen, et al. "Collective classification in network data." AI Magazine, 2008.](https://linqspub.soe.ucsc.edu/basilic/web/Publications/2008/sen:aimag08/).
#
# No additional preprocessing was done to the dataset. The original dataset can be downloaded [here](https://linqs-data.soe.ucsc.edu/public/lbc/citeseer.tgz).
#
# Dataset summary:
# * 3703 unique word attributes
# * 3312 scientific publications
# * Labels for classifying the papers are:
#     * Agents
#     * AI
#     * DB
#     * IR
#     * ML
#     * HCI
# * Each publication can have only one label.
#
# ## Experiment
#
# The goal is to correctly classify the paper cateogry and examine the performance difference between the Neural Graph Learning model and a base model.
#
# To proberly examine the performance difference between the models, each model is trainined with traning sizes from 0.1 to 0.85 with 0.5 incrementes. The models is run 5 times at each traning sizes whereafter the average results are presented in a graph.
#
# ## References
#
# Large parts of the code for preprocessing, loading train, test and validation data, evaluation, generation of Keras functional models is modefied from Tensorflows tutorials and resources introducing neural structed learning. The original code can be found here: [Tensorflows github](https://github.com/tensorflow/neural-structured-learning) and [Guide and Tutorials](https://www.tensorflow.org/neural_structured_learning/framework).
# Furthermore, additional information about the API can be found [here](https://www.tensorflow.org/neural_structured_learning/api_docs/python/nsl).

# %% [markdown]
# # Experiment

# %% [markdown]
# ### Importing needed libraries

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import neural_structured_learning as nsl
import tensorflow as tf

import csv
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Getting the data

# %%
# !tar -C /tmp -xvzf /Users/johanweisshansen/Documents/DTU/3.semester/advanced_project/oticon_project/terror_data/nsl/dataset_test_6/citeseer/citeseer.tgz
# Out:
# x citeseer/
# x citeseer/citeseer.content
# x citeseer/README
# x citeseer/citeseer.cites

# %% [markdown]
# ## Defining hyperparameters

# %%
class HParams(object):
  """Hyperparameters used for training."""
  def __init__(self):
    ### dataset parameters
    self.num_classes = 6
    self.max_seq_length = 3703 # distinct features
    ### neural graph learning parameters
    self.distance_type = nsl.configs.DistanceType.L2
    self.graph_regularization_multiplier = 0.1
    self.num_neighbors = 1
    ### model architecture
    self.num_fc_units = [50,50]
    ### training parameters
    self.train_epochs = 150
    self.batch_size = 150
    self.dropout_rate = 0.5
    ### eval parameters
    self.eval_steps = None  # All instances in the test set are evaluated.

HPARAMS = HParams()

# %% [markdown]
# ## Load train and test data

# %%
def parse_example(example_proto):

    feature_spec = {
        'words':
            tf.io.FixedLenFeature([HPARAMS.max_seq_length],
                                tf.int64,
                                default_value=tf.constant(
                                    0,
                                    dtype=tf.int64,
                                    shape=[HPARAMS.max_seq_length])),
        'label':
          tf.io.FixedLenFeature((), tf.int64, default_value=-1),
    }
    # We also extract corresponding neighbor features in a similar manner to
  # the features above.
    for i in range(HPARAMS.num_neighbors):
        nbr_feature_key = '{}{}_{}'.format(NBR_FEATURE_PREFIX, i, 'words')
        nbr_weight_key = '{}{}{}'.format(NBR_FEATURE_PREFIX, i, NBR_WEIGHT_SUFFIX)
        feature_spec[nbr_feature_key] = tf.io.FixedLenFeature(
            [HPARAMS.max_seq_length],
            tf.int64,
            default_value=tf.constant(
            0, dtype=tf.int64, shape=[HPARAMS.max_seq_length]))

    # We assign a default value of 0.0 for the neighbor weight so that
    # graph regularization is done on samples based on their exact number
    # of neighbors. In other words, non-existent neighbors are discounted.
    feature_spec[nbr_weight_key] = tf.io.FixedLenFeature(
        [1], tf.float32, default_value=tf.constant([0.0]))

    features = tf.io.parse_single_example(example_proto, feature_spec)

    labels = features.pop('label')
    return features, labels


def make_dataset(file_path, training=False):
     #Creates a `tf.data.TFRecordDataset`.

    dataset = tf.data.TFRecordDataset([file_path])
    if training:
        dataset = dataset.shuffle(10000)
    dataset = dataset.map(parse_example)
    dataset = dataset.batch(HPARAMS.batch_size)
    return dataset

# %% [markdown]
# ## Functional base model

# %%
def functional_model(hparams):
    """Creates a functional API-based multi-layer perceptron model."""
    inputs = tf.keras.Input(shape=(hparams.max_seq_length,), dtype='int64', name='words')

  # casting one hot to floating point format.
    cur_layer = tf.keras.layers.Lambda(
      lambda x: tf.keras.backend.cast(x, tf.float32))(
          inputs)

    for num_units in hparams.num_fc_units:
        cur_layer = tf.keras.layers.Dense(num_units, activation='relu')(cur_layer)
        cur_layer = tf.keras.layers.Dropout(hparams.dropout_rate)(cur_layer)
        cur_layer = tf.keras.layers.BatchNormalization()(cur_layer)

    outputs = tf.keras.layers.Dense(
      hparams.num_classes, activation='softmax')(
          cur_layer)

    model = tf.keras.Model(inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Function to evaluate models

# %%
# Helper function to print evaluation metrics.
def print_metrics(model_desc, eval_metrics):
    print('\n')
    print('Eval accuracy for ', model_desc, ': ', eval_metrics['accuracy'])
    print('Eval loss for ', model_desc, ': ', eval_metrics['loss'])
    if 'graph_loss' in eval_metrics:
        print('Eval graph loss for ', model_desc, ': ', eval_metrics['graph_loss'])

# %% [markdown]
# # Iterating over training size

# %%
import numpy as np
# defining the training size we need to iterate over
train_percentage = []
train_percentage.append(0.01) # starting the list at 1% of training data

for i in np.arange(0.05, 0.9, 0.05):
    train_percentage.append(round(i,2))

# %%
# lists for holding results
graph_accuracy_by_training_size_avg = []
base_accuracy_by_training_size_avg = []

for j in range(5):
    
    base_model_results_list = []
    graph_model_results_list = []

    for i in range(len(train_percentage)):

        print("---------------------training at percentage ", train_percentage[i], "--------------------------------")

        pass_train_percent = train_percentage[i]

        # running the data trough the preprocessing script
        # !python preprocessing_citeseer_dataset.py \
        --input_content=/tmp/citeseer/citeseer.content \
        --input_graph=/tmp/citeseer/citeseer.cites \
        --max_nbrs=3 \
        --train_percentage=$pass_train_percent\
        --output_train_data=/tmp/citeseer/train_merged_examples.tfr \
        --output_test_data=/tmp/citeseer/test_examples.tfr

        ### Experiment dataset
#         TRAIN_DATA_PATH = '/tmp/CustomTerroristRel/train_merged_examples.tfr'
#         TEST_DATA_PATH = '/tmp/CustomTerroristRel/test_examples.tfr'

        ### Constants used to identify neighbor features in the input.
        NBR_FEATURE_PREFIX = 'NL_nbr_'
        NBR_WEIGHT_SUFFIX = '_weight'

        # generating train and test data
        train_dataset = make_dataset('/tmp/citeseer/train_merged_examples.tfr', training=True)
        test_dataset = make_dataset('/tmp/citeseer/test_examples.tfr')


        # ----------------------------------------training base model--------------------------------------
        # Create a base MLP model using the functional API.
        base_model = functional_model(HPARAMS)

        # Compile and train the base MLP model
        base_model.compile(
        optimizer='adam',
        #sparse_categorical_crossentropy
        #categorical_crossentropy
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy'],
        lr=0.01, clipnorm=1.)
        base_model_history = base_model.fit(train_dataset, epochs=HPARAMS.train_epochs, verbose=0, validation_data=test_dataset)

        # evaluate base model
        eval_results = dict(
        zip(base_model.metrics_names,
            base_model.evaluate(test_dataset, steps=HPARAMS.eval_steps)))
        print_metrics('Base MLP model', eval_results)

        base_model_results_list.append(eval_results)


        # ----------------------------------------training graph model--------------------------------------
        # Build a new base MLP model.
        base_reg_model = functional_model(
        HPARAMS)

        # Wrap the base MLP model with graph regularization.
        graph_reg_config = nsl.configs.make_graph_reg_config(
            max_neighbors=HPARAMS.num_neighbors,
            multiplier=HPARAMS.graph_regularization_multiplier,
            distance_type=HPARAMS.distance_type,
            sum_over_axis=-1)

        graph_reg_model = nsl.keras.GraphRegularization(base_reg_model,
                                                        graph_reg_config)
        graph_reg_model.compile(
            optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
        graph_reg_model_history = graph_reg_model.fit(train_dataset, epochs=HPARAMS.train_epochs, verbose=0, validation_data=test_dataset)

        # evaluate graph model 
        eval_results = dict(
        zip(graph_reg_model.metrics_names,
            graph_reg_model.evaluate(test_dataset, steps=HPARAMS.eval_steps)))

        print_metrics('MLP + graph regularization', eval_results)
        graph_model_results_list.append(eval_results)
        
    print("--------------------- iteration: ", j, "------------------------" )
    graph_accuracy_by_training_size_avg.append(graph_model_results_list)
    base_accuracy_by_training_size_avg.append(base_model_results_list)
# Out:
# ---------------------training at percentage  0.01 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# Done creating and writing 41 merged tf.train.Examples (0.04 seconds).
# Out-degree histogram: [(1, 18), (2, 9), (3, 14)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.06 minutes.
# 22/22 [==============================] - 0s 17ms/step - loss: 1.7434 - accuracy: 0.2806
#
#
# Eval accuracy for  Base MLP model :  0.2806481
# Eval loss for  Base MLP model :  1.743429113518108
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 22/22 [==============================] - 0s 15ms/step - loss: 1.6964 - accuracy: 0.3045 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.30449405
# Eval loss for  MLP + graph regularization :  1.6963692036542026
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.05 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# Done creating and writing 188 merged tf.train.Examples (0.17 seconds).
# Out-degree histogram: [(1, 77), (2, 42), (3, 69)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.06 minutes.
# 21/21 [==============================] - 0s 15ms/step - loss: 1.4176 - accuracy: 0.5054
#
#
# Eval accuracy for  Base MLP model :  0.5054417
# Eval loss for  Base MLP model :  1.4175517048154558
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 21/21 [==============================] - 0s 16ms/step - loss: 1.2891 - accuracy: 0.5471 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.54705507
# Eval loss for  MLP + graph regularization :  1.289111472311474
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.1 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:35:48.528645 4757179840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# Done creating and writing 344 merged tf.train.Examples (0.31 seconds).
# Out-degree histogram: [(1, 146), (2, 78), (3, 120)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.07 minutes.
# 20/20 [==============================] - 0s 17ms/step - loss: 1.1564 - accuracy: 0.5900
#
#
# Eval accuracy for  Base MLP model :  0.58995956
# Eval loss for  Base MLP model :  1.1563685089349747
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 20/20 [==============================] - 0s 14ms/step - loss: 1.1467 - accuracy: 0.6233 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.62331533
# Eval loss for  MLP + graph regularization :  1.1466784089803697
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.15 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:37:38.112041 4642807232 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# Done creating and writing 505 merged tf.train.Examples (0.45 seconds).
# Out-degree histogram: [(1, 216), (2, 118), (3, 171)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.07 minutes.
# 19/19 [==============================] - 0s 13ms/step - loss: 1.1006 - accuracy: 0.6455
#
#
# Eval accuracy for  Base MLP model :  0.64552903
# Eval loss for  Base MLP model :  1.1005685862741972
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 19/19 [==============================] - 0s 14ms/step - loss: 1.1775 - accuracy: 0.6548 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.6547916
# Eval loss for  MLP + graph regularization :  1.1774548637239557
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.2 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:39:28.590541 4628995520 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:39:28.661357 4628995520 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:39:28.694252 4628995520 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 660 merged tf.train.Examples (0.60 seconds).
# Out-degree histogram: [(1, 293), (2, 151), (3, 216)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.07 minutes.
# 18/18 [==============================] - 0s 15ms/step - loss: 1.1728 - accuracy: 0.6606
#
#
# Eval accuracy for  Base MLP model :  0.6606335
# Eval loss for  Base MLP model :  1.1727529995971255
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 18/18 [==============================] - 0s 14ms/step - loss: 1.2792 - accuracy: 0.6750 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.6749623
# Eval loss for  MLP + graph regularization :  1.2791647381252713
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.25 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.00 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:41:21.772196 4469210560 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:41:21.856943 4469210560 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:41:21.893161 4469210560 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 824 merged tf.train.Examples (0.74 seconds).
# Out-degree histogram: [(1, 359), (2, 190), (3, 275)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.07 minutes.
# 17/17 [==============================] - 0s 14ms/step - loss: 1.1556 - accuracy: 0.6809
#
#
# Eval accuracy for  Base MLP model :  0.68086815
# Eval loss for  Base MLP model :  1.1555558723561905
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 17/17 [==============================] - 0s 14ms/step - loss: 1.3607 - accuracy: 0.6833 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.68327975
# Eval loss for  MLP + graph regularization :  1.3606620466007906
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.3 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:43:16.232271 4683554240 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:43:16.269788 4683554240 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:43:16.336837 4683554240 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:43:16.379945 4683554240 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 994 merged tf.train.Examples (0.95 seconds).
# Out-degree histogram: [(1, 426), (2, 232), (3, 336)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.07 minutes.
# 16/16 [==============================] - 0s 16ms/step - loss: 1.2764 - accuracy: 0.6786
#
#
# Eval accuracy for  Base MLP model :  0.6786022
# Eval loss for  Base MLP model :  1.2764420956373215
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 16/16 [==============================] - 0s 14ms/step - loss: 1.3547 - accuracy: 0.6950 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.6949957
# Eval loss for  MLP + graph regularization :  1.3546911403536797
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.35 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:45:13.841928 4412247488 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:45:13.887830 4412247488 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:45:14.004215 4412247488 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:45:14.097995 4412247488 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 1165 merged tf.train.Examples (1.25 seconds).
# Out-degree histogram: [(1, 503), (2, 268), (3, 394)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 15/15 [==============================] - 0s 14ms/step - loss: 1.2935 - accuracy: 0.6907
#
#
# Eval accuracy for  Base MLP model :  0.6907312
# Eval loss for  Base MLP model :  1.2934901555379232
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 15/15 [==============================] - 0s 14ms/step - loss: 1.4393 - accuracy: 0.7010 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7009781
# Eval loss for  MLP + graph regularization :  1.4393147150675456
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.4 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:47:15.755579 4545457600 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:47:15.802513 4545457600 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:47:15.897776 4545457600 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:47:15.964066 4545457600 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 1329 merged tf.train.Examples (1.18 seconds).
# Out-degree histogram: [(1, 573), (2, 310), (3, 446)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 14/14 [==============================] - 0s 13ms/step - loss: 1.3358 - accuracy: 0.6959
#
#
# Eval accuracy for  Base MLP model :  0.6959153
# Eval loss for  Base MLP model :  1.335838407278061
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 14/14 [==============================] - 0s 14ms/step - loss: 1.5349 - accuracy: 0.7115 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.71154815
# Eval loss for  MLP + graph regularization :  1.5348792118685586
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.45 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.00 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:49:11.467023 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 11:49:11.596658 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:49:11.633052 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 11:49:11.649662 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:49:11.675770 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 11:49:11.758030 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:49:11.834755 4685618624 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 1491 merged tf.train.Examples (1.30 seconds).
# Out-degree histogram: [(1, 631), (2, 347), (3, 513)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 13/13 [==============================] - 0s 13ms/step - loss: 1.4133 - accuracy: 0.7073
#
#
# Eval accuracy for  Base MLP model :  0.7073037
# Eval loss for  Base MLP model :  1.4132726375873272
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 13/13 [==============================] - 0s 14ms/step - loss: 1.5689 - accuracy: 0.7183 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.71828663
# Eval loss for  MLP + graph regularization :  1.5688756245833178
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.5 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.00 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:51:09.666510 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 11:51:09.810678 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:51:09.849688 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 11:51:09.865885 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:51:09.896276 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 11:51:09.984468 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:51:10.069986 4415389120 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 1624 merged tf.train.Examples (1.45 seconds).
# Out-degree histogram: [(1, 678), (2, 382), (3, 564)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 12/12 [==============================] - 0s 14ms/step - loss: 1.3565 - accuracy: 0.7103
#
#
# Eval accuracy for  Base MLP model :  0.7103081
# Eval loss for  Base MLP model :  1.3565156608819962
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 12/12 [==============================] - 0s 13ms/step - loss: 1.5167 - accuracy: 0.7162 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.71623224
# Eval loss for  MLP + graph regularization :  1.5167179753383
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.55 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:53:07.735029 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 11:53:07.897433 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:53:07.948242 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 11:53:07.966825 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:53:08.004592 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 11:53:08.100251 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:53:08.202683 4650544576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 1807 merged tf.train.Examples (1.65 seconds).
# Out-degree histogram: [(1, 743), (2, 428), (3, 636)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 11/11 [==============================] - 0s 13ms/step - loss: 1.2809 - accuracy: 0.7243
#
#
# Eval accuracy for  Base MLP model :  0.72425246
# Eval loss for  Base MLP model :  1.2809079018506138
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 11/11 [==============================] - 0s 13ms/step - loss: 1.5194 - accuracy: 0.7482 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.74817276
# Eval loss for  MLP + graph regularization :  1.5194375244053928
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.6 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:55:09.647325 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 11:55:09.655611 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 11:55:09.831160 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:55:09.882133 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 11:55:09.898904 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:55:09.944875 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 11:55:10.051331 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:55:10.186812 4601392576 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 1982 merged tf.train.Examples (1.80 seconds).
# Out-degree histogram: [(1, 797), (2, 478), (3, 707)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 9/9 [==============================] - 0s 14ms/step - loss: 1.3668 - accuracy: 0.7241
#
#
# Eval accuracy for  Base MLP model :  0.7240602
# Eval loss for  Base MLP model :  1.3668420248561435
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 9/9 [==============================] - 0s 15ms/step - loss: 1.3713 - accuracy: 0.7444 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7443609
# Eval loss for  MLP + graph regularization :  1.371311088403066
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.65 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.00 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:57:13.239305 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 11:57:13.247386 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 11:57:13.433252 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:57:13.489999 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 11:57:13.509032 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:57:13.554996 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 11:57:13.584151 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 11:57:13.672699 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:57:13.792129 4601556416 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 2153 merged tf.train.Examples (1.92 seconds).
# Out-degree histogram: [(1, 879), (2, 512), (3, 762)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.08 minutes.
# 8/8 [==============================] - 0s 15ms/step - loss: 1.3860 - accuracy: 0.7317
#
#
# Eval accuracy for  Base MLP model :  0.73166525
# Eval loss for  Base MLP model :  1.3859862312674522
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 8/8 [==============================] - 0s 15ms/step - loss: 1.4382 - accuracy: 0.7489 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7489215
# Eval loss for  MLP + graph regularization :  1.438199482858181
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.7 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.00 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 11:59:24.129694 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 11:59:24.139688 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 11:59:24.342262 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 11:59:24.404921 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 11:59:24.425075 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 11:59:24.475397 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 11:59:24.510160 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 11:59:24.606716 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 11:59:24.737277 4627676608 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 2316 merged tf.train.Examples (2.14 seconds).
# Out-degree histogram: [(1, 950), (2, 556), (3, 810)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.09 minutes.
# 7/7 [==============================] - 0s 17ms/step - loss: 1.4541 - accuracy: 0.7450
#
#
# Eval accuracy for  Base MLP model :  0.7449799
# Eval loss for  Base MLP model :  1.4540501151766096
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 7/7 [==============================] - 0s 15ms/step - loss: 1.4709 - accuracy: 0.7610 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7610442
# Eval loss for  MLP + graph regularization :  1.470928932939257
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.75 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.01 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 12:01:43.561491 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 12:01:43.576189 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 12:01:43.866084 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 12:01:43.949404 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 12:01:43.959924 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 12:01:43.986607 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 12:01:44.063179 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 12:01:44.116431 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 12:01:44.260184 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 12:01:44.442844 4578442688 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 2471 merged tf.train.Examples (2.67 seconds).
# Out-degree histogram: [(1, 1008), (2, 599), (3, 864)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.10 minutes.
# 6/6 [==============================] - 0s 16ms/step - loss: 1.4516 - accuracy: 0.7455
#
#
# Eval accuracy for  Base MLP model :  0.74554104
# Eval loss for  Base MLP model :  1.4516259829203289
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 6/6 [==============================] - 0s 15ms/step - loss: 1.5296 - accuracy: 0.7539 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.75386447
# Eval loss for  MLP + graph regularization :  1.5295573671658833
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.8 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.00 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 12:04:00.273777 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 12:04:00.284909 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 12:04:00.297379 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "38137"
# W1210 12:04:00.508574 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 12:04:00.571161 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 12:04:00.581068 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 12:04:00.601866 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 12:04:00.658487 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 12:04:00.697841 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 12:04:00.766993 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "kohrs99using"
# W1210 12:04:00.812208 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 12:04:00.970602 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 12:04:01.006117 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "293457"
# W1210 12:04:01.006202 4628557248 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "gabbard97taxonomy"
# Done creating and writing 2634 merged tf.train.Examples (2.35 seconds).
# Out-degree histogram: [(1, 1082), (2, 636), (3, 916)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.09 minutes.
# 5/5 [==============================] - 0s 15ms/step - loss: 1.5998 - accuracy: 0.7375
#
#
# Eval accuracy for  Base MLP model :  0.7374631
# Eval loss for  Base MLP model :  1.5997560501098633
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 5/5 [==============================] - 0s 14ms/step - loss: 1.5226 - accuracy: 0.7625 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7625369
# Eval loss for  MLP + graph regularization :  1.5226041078567505
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.85 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 12:06:14.925850 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 12:06:14.937445 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 12:06:14.950575 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "38137"
# W1210 12:06:15.172730 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 12:06:15.239117 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 12:06:15.249700 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 12:06:15.273479 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 12:06:15.332837 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 12:06:15.376867 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 12:06:15.449892 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "kohrs99using"
# W1210 12:06:15.498462 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 12:06:15.667035 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 12:06:15.704375 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "293457"
# W1210 12:06:15.704493 4381822400 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "gabbard97taxonomy"
# Done creating and writing 2813 merged tf.train.Examples (2.51 seconds).
# Out-degree histogram: [(1, 1149), (2, 679), (3, 985)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.09 minutes.
# 4/4 [==============================] - 0s 13ms/step - loss: 1.6236 - accuracy: 0.7455
#
#
# Eval accuracy for  Base MLP model :  0.74549097
# Eval loss for  Base MLP model :  1.6235853731632233
# ...
# W1210 14:24:58.811431 4615732672 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 14:24:58.844627 4615732672 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 14:24:58.951365 4615732672 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 14:24:59.082804 4615732672 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 2153 merged tf.train.Examples (2.13 seconds).
# Out-degree histogram: [(1, 879), (2, 512), (3, 762)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.09 minutes.
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3217 - accuracy: 0.7412
#
#
# Eval accuracy for  Base MLP model :  0.74115616
# Eval loss for  Base MLP model :  1.3217325806617737
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 8/8 [==============================] - 0s 20ms/step - loss: 1.3841 - accuracy: 0.7550 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7549612
# Eval loss for  MLP + graph regularization :  1.384149119257927
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.7 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 14:27:31.770512 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 14:27:31.780816 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 14:27:31.989886 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 14:27:32.055516 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 14:27:32.076356 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 14:27:32.126404 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 14:27:32.161014 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 14:27:32.261611 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 14:27:32.393745 4556918208 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 2316 merged tf.train.Examples (2.31 seconds).
# Out-degree histogram: [(1, 950), (2, 556), (3, 810)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.10 minutes.
# 7/7 [==============================] - 0s 17ms/step - loss: 1.4289 - accuracy: 0.7349
#
#
# Eval accuracy for  Base MLP model :  0.73493975
# Eval loss for  Base MLP model :  1.4288713335990906
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 7/7 [==============================] - 0s 17ms/step - loss: 1.3970 - accuracy: 0.7631 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7630522
# Eval loss for  MLP + graph regularization :  1.396972690309797
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.75 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.00 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 14:30:17.238650 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 14:30:17.251012 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 14:30:17.496209 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 14:30:17.568253 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 14:30:17.579120 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 14:30:17.606555 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 14:30:17.667680 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 14:30:17.718565 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 14:30:17.847642 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 14:30:18.017389 4636114368 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# Done creating and writing 2471 merged tf.train.Examples (2.54 seconds).
# Out-degree histogram: [(1, 1008), (2, 599), (3, 864)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.11 minutes.
# 6/6 [==============================] - 0s 19ms/step - loss: 1.4923 - accuracy: 0.7479
#
#
# Eval accuracy for  Base MLP model :  0.74791914
# Eval loss for  Base MLP model :  1.492331902186076
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 6/6 [==============================] - 0s 18ms/step - loss: 1.6104 - accuracy: 0.7539 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.75386447
# Eval loss for  MLP + graph regularization :  1.6104148427645366
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.8 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.01 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 14:32:59.222120 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 14:32:59.234724 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 14:32:59.247864 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "38137"
# W1210 14:32:59.488613 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 14:32:59.560508 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 14:32:59.569941 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 14:32:59.596828 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 14:32:59.663450 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 14:32:59.709435 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 14:32:59.792354 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "kohrs99using"
# W1210 14:32:59.844053 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 14:33:00.024165 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 14:33:00.067482 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "293457"
# W1210 14:33:00.067705 4508859840 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "gabbard97taxonomy"
# Done creating and writing 2634 merged tf.train.Examples (2.68 seconds).
# Out-degree histogram: [(1, 1082), (2, 636), (3, 916)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.10 minutes.
# 5/5 [==============================] - 0s 16ms/step - loss: 1.7034 - accuracy: 0.7419
#
#
# Eval accuracy for  Base MLP model :  0.7418879
# Eval loss for  Base MLP model :  1.7033948659896851
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 5/5 [==============================] - 0s 21ms/step - loss: 1.5433 - accuracy: 0.7640 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7640118
# Eval loss for  MLP + graph regularization :  1.5432761430740356
# Eval graph loss for  MLP + graph regularization :  0.0
# ---------------------training at percentage  0.85 --------------------------------
# preprocessing_citeseer_dataset.py:98: DeprecationWarning: 'U' mode is deprecated
#   with open(in_file, 'rU') as cora_content:
# Reading graph file: /tmp/citeseer/citeseer.cites...
# Done reading 4732 edges from: /tmp/citeseer/citeseer.cites (0.01 seconds).
# Making all edges bi-directional...
# Done (0.01 seconds). Total graph nodes: 3327
# Joining seed and neighbor tf.train.Examples with graph edges...
# W1210 14:35:44.774003 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "197556"
# W1210 14:35:44.786560 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "ghani01hypertext"
# W1210 14:35:44.800554 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "38137"
# W1210 14:35:45.061578 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "nielsen00designing"
# W1210 14:35:45.138191 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 14:35:45.150550 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "weng95shoslifn"
# W1210 14:35:45.175485 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "khardon99relational"
# W1210 14:35:45.242344 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "flach99database"
# W1210 14:35:45.291054 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "95786"
# W1210 14:35:45.371221 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "kohrs99using"
# W1210 14:35:45.425253 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "tobies99pspace"
# W1210 14:35:45.616770 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "raisamo99evaluating"
# W1210 14:35:45.662926 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "293457"
# W1210 14:35:45.663057 4611853760 preprocessing_citeseer_dataset.py:145] No tf.train.Example found for edge target ID: "gabbard97taxonomy"
# Done creating and writing 2813 merged tf.train.Examples (2.93 seconds).
# Out-degree histogram: [(1, 1149), (2, 679), (3, 985)]
# Output training data written to TFRecord file: /tmp/citeseer/train_merged_examples.tfr.
# Output test data written to TFRecord file: /tmp/citeseer/test_examples.tfr.
# Total running time: 0.11 minutes.
# 4/4 [==============================] - 0s 18ms/step - loss: 1.7185 - accuracy: 0.7495
#
#
# Eval accuracy for  Base MLP model :  0.749499
# Eval loss for  Base MLP model :  1.7184712886810303
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /Users/johanweisshansen/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3257 - accuracy: 0.7956 - graph_loss: 0.0000e+00
#
#
# Eval accuracy for  MLP + graph regularization :  0.7955912
# Eval loss for  MLP + graph regularization :  1.325748473405838
# Eval graph loss for  MLP + graph regularization :  0.0
# --------------------- iteration:  4 ------------------------

# %%
graph_avg_list = []
base_avg_list = []

for i in range(0,len(graph_accuracy_by_training_size_avg[0])):
    tmp_avg_value = 0
    for j in range(0,len(graph_accuracy_by_training_size_avg)):
        tmp_avg_value += graph_accuracy_by_training_size_avg[j][i]['accuracy']
    graph_avg_list.append(tmp_avg_value/5)
    
for i in range(0,len(base_accuracy_by_training_size_avg[0])):
    tmp_avg_value = 0
    for j in range(0,len(base_accuracy_by_training_size_avg)):
        tmp_avg_value += base_accuracy_by_training_size_avg[j][i]['accuracy']
    base_avg_list.append(tmp_avg_value/5)

# %%
diff_graph_and_basemodel = []

for i in range(len(base_avg_list)):
    diff_graph_and_basemodel.append(graph_avg_list[i]- base_avg_list[i])

# %%
collected_list = []
collected_list.append(base_avg_list)
collected_list.append(graph_avg_list)
collected_list.append(diff_graph_and_basemodel)

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))

columns = train_percentage
rows = ['base model', 'graph model', 'pref. diff.']

# Get some pastel shades for the colors
n_rows = len(collected_list)

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(train_percentage))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    y_offset = collected_list[row]
    cell_text.append(['%1.3f' % x for x in y_offset])

# Add a table at the bottom of the axes
table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      colLabels=columns,
                      rowColours=['#5b9ac4', '#fd8e39', '#ffffff'],
                      loc='bottom')

table.set_fontsize(14)

# table.auto_set_font_size(False)
table.set_fontsize(14)
table.scale(1, 1.7)
# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)


# plt.plot(graph_collected)
plt.plot(base_avg_list)
plt.plot(graph_avg_list)

# plt.ylabel("Loss in ${0}'s".format(value_increment))
# plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([])
plt.title('Comparison between base and graph model accuracy')
plt.ylabel('accuracy')
# plt.xlabel('training size')
plt.annotate('training size', xy=(1,0), xytext=(-669, -3), ha='left', va='top',
            xycoords='axes fraction', textcoords='offset points')
plt.legend(['base model', 'graph reg model'], loc='upper left')
plt.savefig('plots/citseer_accuracy_graph.png', bbox_inches='tight', pad_inches=0.1)

plt.show()
